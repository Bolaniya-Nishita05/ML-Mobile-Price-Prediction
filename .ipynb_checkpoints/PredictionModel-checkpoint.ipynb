# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle

# %%
df=pd.read_csv("Mobile phone price.csv")

# %%
df
# Out:
#        Brand              Model Storage    RAM Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro  128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra  256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro  128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro  128 GB   6 GB                 6.67
# 4     Google            Pixel 6  128 GB   8 GB                  6.4
# ..       ...                ...     ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G     128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G     128      6                 6.57
# 404    Apple  iPhone 12 Pro Max     128      6                  6.7
# 405     Oppo              Reno3     128      8                  6.4
# 406  Samsung    Galaxy S10 Lite     128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    int64
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    int32
#  3   RAM                     407 non-null    int32
#  4   Screen Size (inches)    407 non-null    float64
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    float64
# dtypes: float64(2), int32(2), int64(2), object(2)
# memory usage: 22.4+ KB

# %%
df["Brand"].unique()
# Out:
# array(['Apple', 'Samsung', 'OnePlus', 'Xiaomi', 'Google', 'Oppo', 'Vivo',
#        'Realme', 'Motorola', 'Nokia', 'Sony', 'LG', 'Asus', 'Blackberry',
#        'CAT', 'Huawei'], dtype=object)

# %%
df["Storage"].unique()
# Out:
# array(['128 GB', '256 GB', '64 GB', '32 GB', '128GB', '256GB', '64GB',
#        '32GB', '256', '64', '128', '512', '32'], dtype=object)

# %%
df["Storage"]=np.array([int(value.replace('GB', '').replace(' ','').replace(',', '')) for value in df["Storage"]])

# %%
df["RAM"].unique()
# Out:
# array(['6 GB', '12 GB', '8 GB', '4 GB', '3 GB', '2 GB', '4GB', '8GB',
#        '6GB', '12GB', '3GB', '2GB', '5GB', '12', '3', '6', '8', '4', '16',
#        '2'], dtype=object)

# %%
df["RAM"]=np.array([int(value.replace('GB', '').replace(' ','').replace(',', '')) for value in df["RAM"]])

# %%
df["Screen Size (inches)"].unique()
# Out:
# array(['6.1', '6.8', '6.7', '6.67', '6.4', '6.55', '6.78', '6.43', '6.5',
#        '6.62', '5.4', '6.2', '6.51', '6.6', '4.7', '6.58', '6.52', '6.44',
#        '6.53', '6.56', '6.8 + 3.9', '4.5', '6.39', '5.9', '5.5', '6.81',
#        '5.99', '6.82', '6.3', '6.22', '6', '6.35', '6.9', '6.76', '6.49',
#        '6.72', '5.7', '6.47', '7.6 (unfolded)', '6.15', '6.57'],
#       dtype=object)

# %%
df["Screen Size (inches)"] = df["Screen Size (inches)"].str.replace(r"[^0-9.]", "", regex=True).str.replace(r"\.(?=.*\.)", "", regex=True)

# %%
df[df["Screen Size (inches)"]==683.9] = 6.83

# %%
df["Screen Size (inches)"] = df["Screen Size (inches)"].astype(float)

# %%
df["Price ($)"].unique()
# Out:
# array(['999', '1199', '899', '279', '799', '249', '699', '329', '449',
#        '199', '299', '379', '179', '729', '599', '139', '189', '399',
#        '259', '159', '229', '499', '129', '529', '369', '1099', '169',
#        '99', '459', '239', '1299', '429', '659', '269', '359', '$799 ',
#        '$399 ', '$699 ', '$329 ', '$999 ', '$549 ', '$1,299 ', '$899 ',
#        '$449 ', '$319 ', '$269 ', '$349 ', '$279 ', '$249 ', '$299 ',
#        '$969 ', '$1,199 ', '$149 ', '$139 ', '$99 ', '$199 ', '$169 ',
#        '$499 ', '$179 ', '$219 ', '$229 ', '$239 ', '$109 ', '$189 ',
#        '$389 ', '$309 ', '$369 ', '$129 ', '$849 ', '$469 ', '$209 ',
#        '$119 ', '$339 ', '$429 ', '$159 ', '$379 ', '$289 ', '130', '749',
#        '149', '969', '649', '349', '419', '1399', '1999', '119', '319',
#        '1049'], dtype=object)

# %%
df["Price ($)"]=np.array([float(value.replace('$', '').replace(',', '')) for value in df["Price ($)"]])

# %%
import seaborn as sns
sns.heatmap(df[["Storage","RAM","Screen Size (inches)","Battery Capacity (mAh)", "Price ($)"]].corr(), annot=True)
# Out:
# <Axes: >

# %%
df[["Storage","RAM","Screen Size (inches)","Battery Capacity (mAh)", "Price ($)"]].corr()
# Out:
#                          Storage       RAM  Screen Size (inches)  \
# Storage                 1.000000  0.691341              0.104106
# RAM                     0.691341  1.000000              0.046963
# Screen Size (inches)    0.104106  0.046963              1.000000
# Battery Capacity (mAh) -0.074952 -0.027627             -0.036321
# Price ($)               0.711050  0.637172              0.098331
#
#                         Battery Capacity (mAh)  Price ($)
# Storage                              -0.074952   0.711050
# RAM                                  -0.027627   0.637172
# Screen Size (inches)                 -0.036321   0.098331
# Battery Capacity (mAh)                1.000000  -0.396581
# Price ($)                            -0.396581   1.000000

# %%
d={}
n=1
print(n)

for i in df["Brand"].unique():
    d[i]=n
    n=n+1
    
d
# Out:
# 1
# {'Apple': 1,
#  'Samsung': 2,
#  'OnePlus': 3,
#  'Xiaomi': 4,
#  'Google': 5,
#  'Oppo': 6,
#  'Vivo': 7,
#  'Realme': 8,
#  'Motorola': 9,
#  'Nokia': 10,
#  'Sony': 11,
#  'LG': 12,
#  'Asus': 13,
#  'Blackberry': 14,
#  'CAT': 15,
#  'Huawei': 16}

# %%
df["Brand"]=df["Brand"].map(d)

# %%
df
# Out:
#      Brand              Model  Storage  RAM  Screen Size (inches)  \
# 0        1      iPhone 13 Pro      128    6                  6.10
# 1        2   Galaxy S21 Ultra      256   12                  6.80
# 2        3              9 Pro      128    8                  6.70
# 3        4  Redmi Note 10 Pro      128    6                  6.67
# 4        5            Pixel 6      128    8                  6.40
# ..     ...                ...      ...  ...                   ...
# 402      2   Galaxy Note20 5G      128    8                  6.70
# 403      4      Mi 10 Lite 5G      128    6                  6.57
# 404      1  iPhone 12 Pro Max      128    6                  6.70
# 405      6              Reno3      128    8                  6.40
# 406      2    Galaxy S10 Lite      128    6                  6.70
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)
# 0          12 + 12 + 12                    3095      999.0
# ...

# %%
sns.heatmap(df[["Brand","Storage","RAM","Screen Size (inches)","Battery Capacity (mAh)", "Price ($)"]].corr(), annot=True)
# Out:
# <Axes: >

# %%
df[["Brand","Storage","RAM","Screen Size (inches)","Battery Capacity (mAh)", "Price ($)"]].corr()
# Out:
#                            Brand   Storage       RAM  Screen Size (inches)  \
# Brand                   1.000000 -0.032590 -0.003070              0.090386
# Storage                -0.032590  1.000000  0.691341              0.104106
# RAM                    -0.003070  0.691341  1.000000              0.046963
# Screen Size (inches)    0.090386  0.104106  0.046963              1.000000
# Battery Capacity (mAh)  0.089920 -0.074952 -0.027627             -0.036321
# Price ($)              -0.115388  0.711050  0.637172              0.098331
#
#                         Battery Capacity (mAh)  Price ($)
# Brand                                 0.089920  -0.115388
# Storage                              -0.074952   0.711050
# RAM                                  -0.027627   0.637172
# Screen Size (inches)                 -0.036321   0.098331
# Battery Capacity (mAh)                1.000000  -0.396581
# Price ($)                            -0.396581   1.000000

# %%
x=df[["Brand","Storage","RAM","Screen Size (inches)","Battery Capacity (mAh)"]]
x
# Out:
#      Brand  Storage  RAM  Screen Size (inches)  Battery Capacity (mAh)
# 0        1      128    6                  6.10                    3095
# 1        2      256   12                  6.80                    5000
# 2        3      128    8                  6.70                    4500
# 3        4      128    6                  6.67                    5020
# 4        5      128    8                  6.40                    4614
# ..     ...      ...  ...                   ...                     ...
# 402      2      128    8                  6.70                    4300
# 403      4      128    6                  6.57                    4160
# 404      1      128    6                  6.70                    3687
# 405      6      128    8                  6.40                    4025
# 406      2      128    6                  6.70                    4500
#
# [407 rows x 5 columns]

# %%
y=df["Price ($)"]
y
# Out:
# 0       999.0
# 1      1199.0
# 2       899.0
# 3       279.0
# 4       799.0
#         ...
# 402    1049.0
# 403     349.0
# 404    1099.0
# 405     429.0
# 406     649.0
# Name: Price ($), Length: 407, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)

# %%
model=RandomForestRegressor(n_estimators=100)

# %%
model.fit(x_train_scaled,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(sc.transform(x_test),y_test)
# Out:
# 0.9304168054111344

# %%
model.predict(sc.transform(x_test))
# Out:
# array([ 254.32142857,  269.86507937,  492.78821429,  794.5       ,
#         209.71333333,  272.67789655,  268.69166667,  229.83333333,
#         136.99446498,  518.        ,  981.        ,  193.46833333,
#         273.80353147,  508.99533814,  411.5       ,  384.79341991,
#        1074.6       ,  207.09063492,  171.9625    ,  192.04432845,
#         964.        ,  254.32142857,  275.55281746,  211.05      ,
#         186.77027056,  139.        ,  244.42190476,  158.21      ,
#         185.27178571,  273.999329  , 1124.6       ,  186.77027056,
#         522.50761905,  448.68166667,  200.755     ,  136.99446498,
#         142.45      ,  285.87      ,  192.04432845,  815.        ,
#         384.79341991,  815.        ,  392.24008658,  376.13952381,
#         909.85      ,  232.15666667,  238.1       ,  559.19950216,
#         778.25      ,  275.95839133,  153.38333333,  363.36666667,
#         274.6472619 ,  143.80535714,  207.09063492,  273.999329  ,
# ...

# %%
f=open("PriceModel.pkl","wb")
pickle.dump(model,f)
f.close()

# %%
f=open("PriceModel.pkl","rb")
model1=pickle.load(f)
f.close()

# %%
model1.score(sc.transform(x_test),y_test)
# Out:
# 0.9304168054111344

# %%
f=open("PriceScaler.pkl","wb")
pickle.dump(sc,f)
f.close()

# %%
f=open("PriceScaler.pkl","rb")
sc1=pickle.load(f)
f.close()

# %%
sc1
# Out:
# StandardScaler()

# %%
import sklearn
print(sklearn.__version__)  # This should print the installed version
# Out:
# 1.6.1

# %%
# import sys
# sys.executable  # Check which Python is being used

# %%
# !where python

# %%
# !pip install --upgrade scikit-learn

# %%
# !python -m ensurepip --default-pip
# !python -m pip install --upgrade pip
